# %%
#B1205058 (Ben)
def Gushing_Spring():
    Yongquan_data = {
        '定位': '在足底部，卷足時足前部凹陷處，約當第2、3趾趾指縫紋頭端與足跟連線的前1/3與後2/3交點上。',
        '解剖': '有指短屈肌腱，指長屈肌腱，第二蚓狀肌，深層為骨間肌；有來自脛前動脈的足底弓；布有足底內側神經支。',
        '主治': '頭頂痛，頭暈，眼花，咽喉痛，舌干，失音，小便不利，大便難，小兒驚風，足心熱，癲疾，霍亂轉筋，昏厥。',
        '配伍': '配然谷治喉痹；配陰陵泉治熱病挾臍急痛，胸脅滿；配水溝、照海治癲癇。配太沖、百會治頭項痛。',
        '刺灸法': '直刺0.5～0.8寸；可灸。'
    }
    return Yongquan_data

#B1205020 (Rigel)
def Yin_Valley():
    Yingu_data = {
        '定位': '該穴位於膕窩內側，屈膝時，當半腱肌肌腱與半膜肌肌腱之間。',
        '解剖': '在半腱肌腱和半膜肌腱之間；有膝上內側動、靜脈；布有股內側皮神經。',
        '主治': '陽痿，疝痛，月經不調，崩漏，小便難，陰中痛，癲狂，膝股內側痛。',
        '配伍': '配照海穴、中極穴治癃閉；配大赫穴、曲骨穴、命門穴治寒疝、陽痿、早泄、月經不調、崩漏。　',
        '刺灸法': '直刺0.8～1.2寸'
    }
    return Yingu_data

#B1205005 (Shang En)
def Vitals_Transporter():
    Huangshu_data = {
        '定位': '在背部，當第4胸椎棘突下，旁開3寸',
        '解剖': '穴下為皮膚、皮下組織、斜方肌筋膜、斜方肌、菱形肌、第四肋間隙。皮膚由第三、四、五胸神經後支內側支分布。在腹內、外斜肌腱膜，腹橫肌腱膜及腹直肌中；有腹壁下動、靜脈肌支；布有第十肋間神經。',
        '主治': '呼吸系統疾病：肺結核，支氣管炎，哮喘；泌尿生殖系統疾病：陽痿，遺精；其它：慢性胃炎，胃出血，神經衰弱，胸膜炎，乳腺炎，貧血。本穴為各種慢性虛損性疾病的常用穴。',
        '配伍': '配天樞穴、足三里穴、大腸俞穴治便秘、泄瀉、痢疾；配中脘穴、足三里穴、內庭穴、天樞穴治胃痛、腹痛、疝痛、排尿、尿道澀痛等症。　',
        '刺灸法': '直刺0.8－1.2寸；可灸。'
    }
    return Huangshu_data

#B1205055 (Jessie)
def Spirit_Seal():
    Shenfeng_data = {
        '定位': '於人體的胸部，當第4肋間隙，前正中線旁開2寸。',
        '解剖': '胸大肌中，有肋間外韌帶及肋間內肌；有第四肋間動、靜脈；布有第四肋間神經前皮支，深部為第四肋間神經。',
        '主治': '咳嗽，氣喘，胸脅支滿，嘔吐，不嗜食，乳癰。',
        '配伍': '配陽陵泉穴、支溝穴治胸脅脹痛。',
        '刺灸法': '斜刺或平刺0.5－0.8寸；可灸。'
    }
    return Shenfeng_data

#B1205047 (Eric)
def Spirit_Storehouse():
    Shencang_data = {
        '定位': '在胸部，當第2肋間隙，前正中線旁開2寸。',
        '解剖': '在胸大肌中，有肋間外韌帶及肋間內肌；有第二肋間動、靜脈；布有第二肋間神經前皮支，深層正當第二肋間神經。',
        '主治': '咳嗽，氣喘，胸痛，煩滿，嘔吐，不嗜食。',
        '配伍': '配天突穴、內關穴、太沖穴治梅核氣；配心俞穴、玉堂穴治胸痹、噎嗝、冠心病、心肌梗塞。',
        '刺灸法': '斜刺或平刺0.5－0.8寸；可灸。'
    }
    return Shencang_data


def Kidney_Meridian_of_Feet_Shaoyin():
    acupoints_info = {
        '涌泉穴': Gushing_Spring(),
        '陰谷穴': Yin_Valley(),
        '肓俞穴': Vitals_Transporter(),
        '神封穴': Spirit_Seal(),
        '神藏穴': Spirit_Storehouse()
    }
    return acupoints_info

def get_acupoint_info(acupoint_name, info_category=None):
    acupoints_info = Kidney_Meridian_of_Feet_Shaoyin()

    acupoint_data = acupoints_info.get(acupoint_name, None)
    if acupoint_data is None:
        return "未找到指定的穴位信息。"

    if info_category:
        return acupoint_data.get(info_category, "未找到指定類別的信息。")

    return acupoint_data

def query_acupoint():
    while True:
        print("\n--- 查詢系統 ---")
        acupoint_name = input("請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:\n(涌泉穴、陰谷穴、肓俞穴、神封穴、神藏穴選擇其一^-^):")
        if acupoint_name == "退出":
            print("\n--- 已退出查詢 ---")
            print("感謝使用本系統，祝你好運owo")
            break

        acupoint_info = get_acupoint_info(acupoint_name)
        if "未找到" in acupoint_info:
            print(f"\n{acupoint_info}\n")
            continue

        while True:
            print(f"\n找到穴位：{acupoint_name}")
            print("可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法")
            info_category = input("請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:")

            if info_category == "返回":
                print("\n返回上一層...\n")
                break
            elif info_category == "全部":
                print(f"\n{acupoint_name} - 全部信息:")
                for category, detail in acupoint_info.items():
                    print(f"{category}: {detail}")
                print()
            elif info_category in ["定位", "解剖", "主治", "配伍", "刺灸法"]:
                category_info = get_acupoint_info(acupoint_name, info_category)
                print(f"\n{acupoint_name} - {info_category}:\n{category_info}\n")
            else:
                print("\n輸入的信息類別不正確，請重新輸入。\n")

            while True:
                next_action = input("輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：")
                if next_action in ["再查詢", "返回"]:
                    break
                else:
                    print("請輸入有效的指令（'再查詢' 或 '返回'）。")
            if next_action == "返回":
                print("\n返回穴位選擇...")
                break

query_acupoint()
# Out:
# --- 查詢系統 ---
# 請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:
# (涌泉穴、陰谷穴、肓俞穴、神封穴、神藏穴選擇其一^-^):涌泉穴
#
# 找到穴位：涌泉穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:定位
#
# 涌泉穴 - 定位:
# 在足底部，卷足時足前部凹陷處，約當第2、3趾趾指縫紋頭端與足跟連線的前1/3與後2/3交點上。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：再查詢
#
# 找到穴位：涌泉穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:解剖
#
# 涌泉穴 - 解剖:
# 有指短屈肌腱，指長屈肌腱，第二蚓狀肌，深層為骨間肌；有來自脛前動脈的足底弓；布有足底內側神經支。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：返回
#
# 返回穴位選擇...
#
# --- 查詢系統 ---
# 請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:
# (涌泉穴、陰谷穴、肓俞穴、神封穴、神藏穴選擇其一^-^):陰谷穴
#
# 找到穴位：陰谷穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:主治
#
# 陰谷穴 - 主治:
# 陽痿，疝痛，月經不調，崩漏，小便難，陰中痛，癲狂，膝股內側痛。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：返回
#
# 返回穴位選擇...
#
# --- 查詢系統 ---
# 請輸入您要查詢的穴位名稱（輸入'退出'結束查詢）:
# (涌泉穴、陰谷穴、肓俞穴、神封穴、神藏穴選擇其一^-^):肓俞穴
#
# 找到穴位：肓俞穴
# 可查詢的信息類別有：定位、解剖、主治、配伍、刺灸法
# 請輸入您要查詢的信息類別（輸入'全部'顯示所有信息，或輸入'返回'返回上一層）:
#
# 輸入的信息類別不正確，請重新輸入。
#
# 輸入'再查詢'以查詢此穴位的其他信息，或輸入'返回'返回穴位選擇：配伍
# 請輸入有效的指令（'再查詢' 或 '返回'）。
# ...
